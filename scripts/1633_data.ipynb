# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
path = "C:/Users/svc_multipatch/Desktop/Cri/Github/coding_scripts/csv/"

# %%
data2 = pd.read_csv(path + 'CN_1633.csv')

# %%
data2.head()
# Out:
#               cellName Patch_cell_container  X.1   X channels dendrite  \
# 0  Q20.26.014.1A.05.01                 none  NaN NaN       no       no
# 1  Q20.26.014.1A.05.02                 none  NaN NaN       no       no
# 2  Q20.26.014.1A.05.03  PQS4_200721_301_A01  NaN NaN       no       no
# 3  Q20.26.014.1A.05.04  PQS4_200721_302_A01  NaN NaN       no       no
# 4  Q20.26.014.1A.10.01  PQS4_200722_301_A01  NaN NaN      yes       no
#
#   multiple_Vm extended_FI noise     experiment  ...  medical_conditions_label  \
# 0          no         yes   yes  Enhancer_Test  ...                       NaN
# 1          no         yes    no  Enhancer_Test  ...                       NaN
# 2          no         yes   yes  Enhancer_Test  ...                       NaN
# 3          no         yes   yes  Enhancer_Test  ...                       NaN
# 4          no         yes   yes  Enhancer_Test  ...                       NaN
#
# ...

# %%
sns.scatterplot(x='RMP', y= 'sag', hue="preparation", data=data2, palette="Greens_d")

# %%
sns.catplot(x='preparation', y= 'rebound', data=data2)

# %%
a = sns.violinplot(x="Tree_call_label", y="res_index_label", jitter= False, data=new, inner=None, scale= 'count')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-e6fd20307ebc> in <module>
# ----> 1 a = sns.violinplot(x="Tree_call_label", y="res_index_label", jitter= False, data=new, inner=None, scale= 'count')
#
# NameError: name 'new' is not defined

# %%
ax = sns.swarmplot(x="sag", y="rebound", data=data2, color="white", edgecolor="gray")

# %%
sns.violinplot(x='preparation',
               y='AP_threshold', 
               data=data2, 
               inner=None, # Remove the bars inside the violins
               palette='rocket_r')
 
sns.swarmplot(x='preparation', 
              y='AP_threshold', 
              data=data2, 
              color='k', # Make points black
              alpha=0.7)

# %%
sns.violinplot(x='preparation',
               y='MaxZ', 
               data=data2, 
               inner=None, # Remove the bars inside the violins
               palette='rocket_r')
 
sns.swarmplot(x='preparation', 
              y='MaxZ', 
              data=data2, 
              color='k', # Make points black
              alpha=0.7)

# %%
nuovo= data2[['FI_slope_initial', 'sag', 'rebound']]

# %%
ax = sns.heatmap(nuovo, cmap="YlGnBu", yticklabels=False) #cbar=False)

# %%
new= data2[['FI_slope_initial', 'sag', 'rebound', 'preparation']]

# %%
a = sns.heatmap(new, cmap="YlGnBu", yticklabels=False, ax='preparation') #cbar=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-79a04dc902bb> in <module>
# ----> 1 a = sns.heatmap(new, cmap="YlGnBu", yticklabels=False, ax='preparation') #cbar=False)
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     515     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     516                           annot_kws, cbar, cbar_kws, xticklabels,
# --> 517                           yticklabels, mask)
#     518
#     519     # Add the pcolormesh kwargs here
#
# ...

# %%
from scipy import stats

# %%
c = sns.JointGrid('FI_slope_initial', 'sag', data=nuovo, space=0)
c = c.plot_joint(sns.kdeplot, cmap="Blues_d")
c = c.plot_marginals(sns.kdeplot, shade=True)
c.annotate(stats.pearsonr)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %%
ax = sns.boxplot(data=new, x='preparation', y='FI_slope_initial')

# %%
sns.pairplot(data=nuovo)

# %%
path = "C:/Users/svc_multipatch/Desktop/Cri/Github/coding_scripts/csv/"
b = pd.read_csv(path + '1633_new.csv')

# %%
ax = sns.heatmap(b, cmap="YlGnBu", yticklabels=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-c5b9b22cc0e3> in <module>
# ----> 1 ax = sns.heatmap(b, cmap="YlGnBu", yticklabels=False)
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     515     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     516                           annot_kws, cbar, cbar_kws, xticklabels,
# --> 517                           yticklabels, mask)
#     518
#     519     # Add the pcolormesh kwargs here
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\matrix.py in __init__(self, data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, cbar, cbar_kws, xticklabels, yticklabels, mask)
# ...

# %%
ephys_heatmap(b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-3f70f8e9c9a9> in <module>
# ----> 1 ephys_heatmap(b)
#
# NameError: name 'ephys_heatmap' is not defined

# %%
path = "C:/Users/svc_multipatch/Desktop/Cri/Github/coding_scripts/csv/"
c = pd.read_csv(path + '1633_new_2.csv')

# %%
sns.scatterplot(x='RMP', y= 'rebound', hue= 'layer', data=c)

# %%
sns.catplot(x='layer', y= 'tau', data=c)

# %%
sns.scatterplot(x= 'X10s_1', y= 'AP_threshold', hue= 'preparation', data=c)

# %%
sns.scatterplot(x= 'X10s_1', y= 'AP_threshold', hue= 'layer', data=c)

# %%
sns.scatterplot(x= 'MaxRn', y= 'SSRn', hue= 'layer', data=c)

# %%
sns.pairplot(data=c)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
sns.catplot(x= 'layer', y= 'rebound', data=c)

# %%
sns.catplot(x= 'layer', y= 'Sag_ratio', data=c)

# %%
sns.catplot(x= 'layer', y= 'RMP', data=c)

# %%
sns.scatterplot(x= 'RMP', y= 'Sag_ratio', hue= 'layer', data=c)

# %%
sns.catplot(x= 'preparation', y= 'rebound', data=c)

# %%
sns.catplot(x= 'preparation', y= 'Sag_ratio', hue= 'layer', data=c)

# %%
sns.catplot(x= 'preparation', y= 'rebound', hue= 'layer', data=c)

# %%
sns.scatterplot(x= 'preparation', y= 'FI_slope_max', hue= 'layer', data=c)

# %%
#cmap = sns.cubehelix_palette(dark=.1, light=1.8, as_cmap=True)
ax = sns.scatterplot(x="f_AHP", y="AP_HW", hue="AP_500", size="AP_500",sizes=(0, 200), hue_norm=(0, 1000), data=data2)

# %%
ax= sns.scatterplot(x="f_AHP", y="AP_HW", sizes=(20, 200), data=data2)

# %%
from matplotlib import pyplot
from mpl_toolkits.mplot3d import Axes3D

# %%
fig = plt.figure(figsize=(8, 8) )
ax = fig.add_subplot(111, projection='3d')
ax.scatter(data2['AP_HW'], data2['AP_500'], data2['f_AHP'], s=80, c = 'b', marker='o')
ax.set_xlabel('AP_HW')
ax.set_ylabel('AP_500')
ax.set_zlabel('f_AHP')
plt.show()
fig.savefig("3d_figure.pdf", bbox_inches='tight')

# %%
cmap = sns.cubehelix_palette(dark=.3, light=.8, as_cmap=True)

# %%
# %matplotlib notebook
plt.rcParams['figure.figsize']=(5,4)
plt.rcParams['figure.dpi']=150

fig=plt.figure()

x='AP_HW'
y='AP_500'
z='f_AHP'

ax= fig.add_subplot (111, projection= '3d')
ax.scatter (xs=old[x], ys=old[y], zs=old[z],
           s=80, c='black', marker='o', edgecolors= 'black', depthshade= False, label='FS_cells')
ax.scatter (xs=new[x], ys=new[y], zs=new[z],
           s=80, c='white', marker='o', edgecolors= 'black', depthshade= False, label='Pyramidal_cells')

ax.set_xlabel(x)
ax.set_ylabel(y)
ax.set_zlabel(z)

ax.legend()
plt.show()
