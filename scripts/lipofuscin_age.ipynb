# %%
import numpy

# %%
numpy.loadtxt(fname= 'lipofuscin.csv', delimiter= ',')
# Out:
# array([[68.,  4.],
#        [60.,  3.],
#        [63.,  3.],
#        [31.,  1.],
#        [31.,  2.],
#        [40.,  2.],
#        [45.,  3.],
#        [51.,  2.],
#        [58.,  2.],
#        [36.,  4.],
#        [59.,  3.],
#        [65.,  3.],
#        [63.,  3.],
#        [28.,  2.],
#        [28.,  3.],
#        [28.,  3.],
#        [46.,  3.],
#        [21.,  1.]])

# %%
data= numpy.loadtxt(fname= 'lipofuscin.csv', delimiter= ',')
print (data.shape)
# Out:
# (18, 2)

# %%
print (data[12,1])
# Out:
# 3.0

# %%
print (data[0:1])
# Out:
# [[68.  4.]]

# %%
print (data[: ,0])
# Out:
# [68. 60. 63. 31. 31. 40. 45. 51. 58. 36. 59. 65. 63. 28. 28. 28. 46. 21.]

# %%
small_data= (data[: ,0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-196-d706b93ef725> in <module>
# ----> 1 small_data= (data[: ,0])
#
# ~\AppData\Local\new\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# ~\AppData\Local\new\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 )
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#    2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, None, None), 0)' is an invalid key

# %%
small_data
# Out:
# array([68., 60., 63., 31., 31., 40., 45., 51., 58., 36., 59., 65., 63.,
#        28., 28., 28., 46., 21.])

# %%
small_data2= (data[: ,1])

# %%
small_data2
# Out:
# array([4., 3., 3., 1., 2., 2., 3., 2., 2., 4., 3., 3., 3., 2., 3., 3., 3.,
#        1.])

# %%
numpy.max(data)
# Out:
# 68.0

# %%
print (numpy.mean(data, axis=0))
# Out:
# [45.61111111  2.61111111]

# %%
import matplotlib.pyplot
plot= matplotlib.pyplot.plot(numpy.mean(data, axis=0))

fig = matplotlib.pyplot.figure(figsize=(10.0, 3.0))

axes = fig.add_subplot(1, 3, 1)
axes.set_xlabel('age')
axes.set_ylabel('lipofuscin score')

matplotlib.pyplot.show()

# %%
import matplotlib.pyplot as plt

fig = plt.figure()
plt.plot(data)
fig.suptitle('lipofuscin_age correlation')
plt.xlabel('age')
plt.ylabel('lipofuscin')
# Out:
# Text(0, 0.5, 'lipofuscin')

# %%
w = 5
h = 7
d = 40
plt.figure(figsize=(w, h), dpi=d)
plt.xlabel("Tacos")
plt.ylabel("Happiness")
x = [small_data2]
y = [small_data]
plt.plot (x, y)
plt.tight_layout()

# %%
#SCATTER PLOT: FIRST GRAPH EVER!!!
import matplotlib.pyplot as plt

fig = plt.figure()

plt.plot([small_data], [small_data2], 'ro')
plt.title('lipofuscin_age correlation')
plt.xlabel('age')
plt.ylabel('lipofuscin')
plt.show()

# %%
import matplotlib.pyplot as plt

fig = plt.figure()

plt.scatter(small_data, small_data2, color='g')
#plt.scatter(small_data, small_data3, color='r') when Meanhwan puts his score
plt.xlabel('age')
plt.ylabel('lipofuscin')
plt.show()

# %%
#HISTOGRAM
import matplotlib.pyplot as plt
import seaborn as sns
sns.set() 

x = [small_data]
plt.hist(x,bins=50)
plt.show()

#this seaborn plot on y axis shows how many times the event of the x axis happened

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig = plt.figure()
plt.scatter(small_data, small_data2, color='g')

m, b = np.polyfit(small_data, small_data2, 1)
plt.title('lipofuscin_age correlation')
plt.xlabel('age')
plt.ylabel('lipofuscin')
plt.plot(small_data, m*small_data + b)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 5), dpi=d)
cri = sns.jointplot(small_data, small_data2, kind='reg')
plt.title('lipofuscin_age correlation')
plt.ylim((0, 5))
plt.xlim ((20, 70))

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 5), dpi=d)
g = sns.jointplot(small_data, small_data2, kind='reg',
                  joint_kws={'line_kws':{'color':'red'}})
plt.title('lipofuscin_age correlation')
plt.ylim((0, 5))
plt.xlim ((20, 70))

plt.show()

# %%
#SCATTER PLOT WITH REGRESSION LINE
import seaborn as sns
import matplotlib.pyplot as plt

fig = plt.figure()
plt.scatter(small_data, small_data2, color='r')

reg_line = sns.regplot(small_data, small_data2, color="b")
plt.scatter(small_data, small_data2, color='r')

plt.title('lipofuscin_age correlation')
plt.xlabel('age')
plt.ylabel('lipofuscin')
plt.plot(small_data, m*small_data + b)
plt.show()

# %%
#BAR PLOT
plt.bar(small_data, small_data2, align='center', alpha=0.5)
plt.xlabel('age')
plt.ylabel('lipofuscin')
plt.show()

# %%
import pandas as pd
data = pd.read_csv('lipofuscin.csv')
data
# Out:
#     68  4
# 0   60  3
# 1   63  3
# 2   31  1
# 3   31  2
# 4   40  2
# 5   45  3
# 6   51  2
# 7   58  2
# 8   36  4
# 9   59  3
# 10  65  3
# 11  63  3
# 12  28  2
# 13  28  3
# 14  28  3
# 15  46  3
# 16  21  1

# %%
#BAR PLOT
plt.bar('age patient', 'score_lipofuscin', align='center', alpha=0.5, data=data)
plt.xlabel('age')
plt.ylabel('lipofuscin')
plt.show()

# %%
x = [small_data]
y = [small_data2]

correlation_matrix = np.corrcoef(small_data, small_data2)
correlation_xy = correlation_matrix[0,1]
r_squared = correlation_xy**2

print(r_squared)
# Out:
# 0.24371231829972298

# %%
x = [small_data]
y = [small_data2]

correlation_matrix = np.corrcoef(small_data, small_data2)
correlation_xy = correlation_matrix[0,1]
r = correlation_xy

print(r)
# Out:
# 0.4936722782370132
